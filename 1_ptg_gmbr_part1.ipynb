# %% [markdown]
# <a href="https://colab.research.google.com/github/jihnrhd/KlasifikasiDaunKentang/blob/main/1_ptg_gmbr_part1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2
gambar = cv2.imread('/content/drive/MyDrive/Tugas_Akhir/IMG_20220629_131135.jpg')

# %%
import matplotlib.pyplot as plt

plt.imshow(gambar)

# %%
gambar.shape
# Out:
# (2250, 4000, 3)

# %%
from PIL import Image

for i in range(0, 2250, 250):
  for j in range(0, 4000, 250):
    im = Image.fromarray(gambar[i:i+250,j:j+250])
    im.save(str(i)+'_'+str(j)+".jpg")

# %%
# !mv *.jpg '/content/new_dataset2/1'

# %%
# !zip -r hasil1.zip '/content/new_dataset2/1'
# Out:
#   adding: content/new_dataset2/1/ (stored 0%)
#   adding: content/new_dataset2/1/750_750.jpg (deflated 1%)
#   adding: content/new_dataset2/1/250_2250.jpg (deflated 1%)
#   adding: content/new_dataset2/1/1000_2750.jpg (deflated 1%)
#   adding: content/new_dataset2/1/250_1000.jpg (deflated 1%)
#   adding: content/new_dataset2/1/500_3750.jpg (deflated 1%)
#   adding: content/new_dataset2/1/1000_1000.jpg (deflated 1%)
#   adding: content/new_dataset2/1/2000_3750.jpg (deflated 1%)
#   adding: content/new_dataset2/1/1250_3000.jpg (deflated 1%)
#   adding: content/new_dataset2/1/250_3250.jpg (deflated 1%)
#   adding: content/new_dataset2/1/750_1000.jpg (deflated 1%)
#   adding: content/new_dataset2/1/250_3000.jpg (deflated 1%)
#   adding: content/new_dataset2/1/250_0.jpg (deflated 1%)
#   adding: content/new_dataset2/1/0_500.jpg (deflated 1%)
#   adding: content/new_dataset2/1/1500_2250.jpg (deflated 1%)
#   adding: content/new_dataset2/1/1250_2500.jpg (deflated 1%)
# ...

# %%
gambar2 = cv2.imread('/content/drive/MyDrive/Tugas_Akhir/IMG_20220629_131205.jpg')

# %%
plt.imshow(gambar2)

# %%
gambar2.shape
# Out:
# (2250, 4000, 3)

# %%
for i in range(0, 2250, 250):
  for j in range(0, 4000, 250):
    im2 = Image.fromarray(gambar2[i:i+250,j:j+250])
    im2.save(str(i)+'_'+str(j)+".jpg")

# %%
# !mv *.jpg '/content/new_dataset2/2'

# %%
# !zip -r hasil2.zip '/content/new_dataset2/2'
# Out:
#   adding: content/new_dataset2/2/ (stored 0%)
#   adding: content/new_dataset2/2/750_750.jpg (deflated 1%)
#   adding: content/new_dataset2/2/250_2250.jpg (deflated 1%)
#   adding: content/new_dataset2/2/1000_2750.jpg (deflated 1%)
#   adding: content/new_dataset2/2/250_1000.jpg (deflated 1%)
#   adding: content/new_dataset2/2/500_3750.jpg (deflated 1%)
#   adding: content/new_dataset2/2/1000_1000.jpg (deflated 1%)
#   adding: content/new_dataset2/2/2000_3750.jpg (deflated 1%)
#   adding: content/new_dataset2/2/1250_3000.jpg (deflated 1%)
#   adding: content/new_dataset2/2/250_3250.jpg (deflated 1%)
#   adding: content/new_dataset2/2/750_1000.jpg (deflated 1%)
#   adding: content/new_dataset2/2/250_3000.jpg (deflated 1%)
#   adding: content/new_dataset2/2/250_0.jpg (deflated 1%)
#   adding: content/new_dataset2/2/0_500.jpg (deflated 1%)
#   adding: content/new_dataset2/2/1500_2250.jpg (deflated 1%)
#   adding: content/new_dataset2/2/1250_2500.jpg (deflated 1%)
# ...

# %%
gambar3 = cv2.imread('/content/drive/MyDrive/Tugas_Akhir/IMG_20220629_131258.jpg')

# %%
plt.imshow(gambar3)

# %%
gambar3.shape
# Out:
# (2250, 4000, 3)

# %%
for i in range(0, 2250, 250):
  for j in range(0, 4000, 250):
    im3 = Image.fromarray(gambar3[i:i+250,j:j+250])
    im3.save(str(i)+'_'+str(j)+".jpg")

# %%
# !mv *.jpg '/content/new_dataset2/3'

# %%
# !zip -r hasil3.zip '/content/new_dataset2/3'
# Out:
#   adding: content/new_dataset2/3/ (stored 0%)
#   adding: content/new_dataset2/3/750_750.jpg (deflated 1%)
#   adding: content/new_dataset2/3/250_2250.jpg (deflated 1%)
#   adding: content/new_dataset2/3/1000_2750.jpg (deflated 1%)
#   adding: content/new_dataset2/3/250_1000.jpg (deflated 1%)
#   adding: content/new_dataset2/3/500_3750.jpg (deflated 1%)
#   adding: content/new_dataset2/3/1000_1000.jpg (deflated 1%)
#   adding: content/new_dataset2/3/2000_3750.jpg (deflated 1%)
#   adding: content/new_dataset2/3/1250_3000.jpg (deflated 1%)
#   adding: content/new_dataset2/3/250_3250.jpg (deflated 1%)
#   adding: content/new_dataset2/3/750_1000.jpg (deflated 1%)
#   adding: content/new_dataset2/3/250_3000.jpg (deflated 1%)
#   adding: content/new_dataset2/3/250_0.jpg (deflated 1%)
#   adding: content/new_dataset2/3/0_500.jpg (deflated 1%)
#   adding: content/new_dataset2/3/1500_2250.jpg (deflated 1%)
#   adding: content/new_dataset2/3/1250_2500.jpg (deflated 1%)
# ...

# %%
gambar4 = cv2.imread('/content/drive/MyDrive/Tugas_Akhir/IMG_20220629_131258.jpg')

# %%
plt.imshow(gambar4)

# %%
gambar4.shape
# Out:
# (2250, 4000, 3)

# %%
for i in range(0, 2250, 250):
  for j in range(0, 4000, 250):
    im4 = Image.fromarray(gambar4[i:i+250,j:j+250])
    im4.save(str(i)+'_'+str(j)+".jpg")

# %%
# !mv *.jpg '/content/new_dataset2/4'

# %%
# !zip -r hasil4.zip '/content/new_dataset2/4'
# Out:
#   adding: content/new_dataset2/4/ (stored 0%)
#   adding: content/new_dataset2/4/750_750.jpg (deflated 1%)
#   adding: content/new_dataset2/4/250_2250.jpg (deflated 1%)
#   adding: content/new_dataset2/4/1000_2750.jpg (deflated 1%)
#   adding: content/new_dataset2/4/250_1000.jpg (deflated 1%)
#   adding: content/new_dataset2/4/500_3750.jpg (deflated 1%)
#   adding: content/new_dataset2/4/1000_1000.jpg (deflated 1%)
#   adding: content/new_dataset2/4/2000_3750.jpg (deflated 1%)
#   adding: content/new_dataset2/4/1250_3000.jpg (deflated 1%)
#   adding: content/new_dataset2/4/250_3250.jpg (deflated 1%)
#   adding: content/new_dataset2/4/750_1000.jpg (deflated 1%)
#   adding: content/new_dataset2/4/250_3000.jpg (deflated 1%)
#   adding: content/new_dataset2/4/250_0.jpg (deflated 1%)
#   adding: content/new_dataset2/4/0_500.jpg (deflated 1%)
#   adding: content/new_dataset2/4/1500_2250.jpg (deflated 1%)
#   adding: content/new_dataset2/4/1250_2500.jpg (deflated 1%)
# ...

# %%
gambar5 = cv2.imread('/content/drive/MyDrive/Tugas_Akhir/IMG_20220629_131321.jpg')

# %%
plt.imshow(gambar5)

# %%
gambar5.shape
# Out:
# (2250, 4000, 3)

# %%
for i in range(0, 2250, 250):
  for j in range(0, 4000, 250):
    im5= Image.fromarray(gambar5[i:i+250,j:j+250])
    im5.save(str(i)+'_'+str(j)+".jpg")

# %%
# !mv *.jpg '/content/new_dataset2/5'

# %%
# !zip -r hasil5.zip '/content/new_dataset2/5'
# Out:
#   adding: content/new_dataset2/5/ (stored 0%)
#   adding: content/new_dataset2/5/750_750.jpg (deflated 1%)
#   adding: content/new_dataset2/5/250_2250.jpg (deflated 1%)
#   adding: content/new_dataset2/5/1000_2750.jpg (deflated 1%)
#   adding: content/new_dataset2/5/250_1000.jpg (deflated 1%)
#   adding: content/new_dataset2/5/500_3750.jpg (deflated 1%)
#   adding: content/new_dataset2/5/1000_1000.jpg (deflated 1%)
#   adding: content/new_dataset2/5/2000_3750.jpg (deflated 2%)
#   adding: content/new_dataset2/5/1250_3000.jpg (deflated 1%)
#   adding: content/new_dataset2/5/250_3250.jpg (deflated 1%)
#   adding: content/new_dataset2/5/750_1000.jpg (deflated 1%)
#   adding: content/new_dataset2/5/250_3000.jpg (deflated 1%)
#   adding: content/new_dataset2/5/250_0.jpg (deflated 1%)
#   adding: content/new_dataset2/5/0_500.jpg (deflated 1%)
#   adding: content/new_dataset2/5/1500_2250.jpg (deflated 1%)
#   adding: content/new_dataset2/5/1250_2500.jpg (deflated 1%)
# ...

# %%
gambar6 = cv2.imread('/content/drive/MyDrive/Tugas_Akhir/IMG_20220629_131436.jpg')

# %%
plt.imshow(gambar6)

# %%
gambar6.shape
# Out:
# (2250, 4000, 3)

# %%
for i in range(0, 2250, 250):
  for j in range(0, 4000, 250):
    im6 = Image.fromarray(gambar6[i:i+250,j:j+250])
    im6.save(str(i)+'_'+str(j)+".jpg")

# %%
# !mv *.jpg '/content/new_dataset2/6'

# %%
# !zip -r hasil6.zip '/content/new_dataset2/6'
# Out:
#   adding: content/new_dataset2/6/ (stored 0%)
#   adding: content/new_dataset2/6/750_750.jpg (deflated 1%)
#   adding: content/new_dataset2/6/250_2250.jpg (deflated 1%)
#   adding: content/new_dataset2/6/1000_2750.jpg (deflated 1%)
#   adding: content/new_dataset2/6/250_1000.jpg (deflated 1%)
#   adding: content/new_dataset2/6/500_3750.jpg (deflated 1%)
#   adding: content/new_dataset2/6/1000_1000.jpg (deflated 1%)
#   adding: content/new_dataset2/6/2000_3750.jpg (deflated 1%)
#   adding: content/new_dataset2/6/1250_3000.jpg (deflated 1%)
#   adding: content/new_dataset2/6/250_3250.jpg (deflated 1%)
#   adding: content/new_dataset2/6/750_1000.jpg (deflated 1%)
#   adding: content/new_dataset2/6/250_3000.jpg (deflated 1%)
#   adding: content/new_dataset2/6/250_0.jpg (deflated 1%)
#   adding: content/new_dataset2/6/0_500.jpg (deflated 1%)
#   adding: content/new_dataset2/6/1500_2250.jpg (deflated 2%)
#   adding: content/new_dataset2/6/1250_2500.jpg (deflated 1%)
# ...

# %%
gambar7 = cv2.imread('/content/drive/MyDrive/Tugas_Akhir/IMG_20220629_131520.jpg')

# %%
plt.imshow(gambar7)

# %%
gambar7.shape
# Out:
# (2250, 4000, 3)

# %%
for i in range(0, 2250, 250):
  for j in range(0, 4000, 250):
    im7 = Image.fromarray(gambar7[i:i+250,j:j+250])
    im7.save(str(i)+'_'+str(j)+".jpg")

# %%
# !mv *.jpg '/content/new_dataset2/7'

# %%
# !zip -r hasil7.zip '/content/new_dataset2/7'
# Out:
#   adding: content/sample_data/7/ (stored 0%)
#   adding: content/sample_data/7/1000_2500.jpg (deflated 1%)
#   adding: content/sample_data/7/1250_2000.jpg (deflated 1%)
#   adding: content/sample_data/7/1750_2250.jpg (deflated 1%)
#   adding: content/sample_data/7/0_3000.jpg (deflated 1%)
#   adding: content/sample_data/7/1750_2000.jpg (deflated 1%)
#   adding: content/sample_data/7/2000_2250.jpg (deflated 1%)
#   adding: content/sample_data/7/750_2250.jpg (deflated 1%)
#   adding: content/sample_data/7/1750_750.jpg (deflated 1%)
#   adding: content/sample_data/7/0_2500.jpg (deflated 1%)
#   adding: content/sample_data/7/1500_750.jpg (deflated 1%)
#   adding: content/sample_data/7/0_3750.jpg (deflated 3%)
#   adding: content/sample_data/7/1500_2750.jpg (deflated 1%)
#   adding: content/sample_data/7/250_1000.jpg (deflated 1%)
#   adding: content/sample_data/7/500_1000.jpg (deflated 1%)
#   adding: content/sample_data/7/0_750.jpg (deflated 1%)
# ...

# %%
gambar8 = cv2.imread('/content/drive/MyDrive/Tugas_Akhir/IMG_20220629_131548.jpg')

# %%
plt.imshow(gambar8)

# %%
gambar8.shape
# Out:
# (2250, 4000, 3)

# %%
for i in range(0, 2250, 250):
  for j in range(0, 4000, 250):
    im8 = Image.fromarray(gambar2[i:i+250,j:j+250])
    im8.save(str(i)+'_'+str(j)+".jpg")

# %%
# !mv *.jpg '/content/sample_data/8'

# %%
# !zip -r hasil8.zip '/content/sample_data/8'
# Out:
#   adding: content/sample_data/8/ (stored 0%)
#   adding: content/sample_data/8/1000_2500.jpg (deflated 1%)
#   adding: content/sample_data/8/1250_2000.jpg (deflated 1%)
#   adding: content/sample_data/8/1750_2250.jpg (deflated 1%)
#   adding: content/sample_data/8/0_3000.jpg (deflated 1%)
#   adding: content/sample_data/8/1750_2000.jpg (deflated 1%)
#   adding: content/sample_data/8/2000_2250.jpg (deflated 1%)
#   adding: content/sample_data/8/750_2250.jpg (deflated 1%)
#   adding: content/sample_data/8/1750_750.jpg (deflated 1%)
#   adding: content/sample_data/8/0_2500.jpg (deflated 1%)
#   adding: content/sample_data/8/1500_750.jpg (deflated 1%)
#   adding: content/sample_data/8/0_3750.jpg (deflated 3%)
#   adding: content/sample_data/8/1500_2750.jpg (deflated 1%)
#   adding: content/sample_data/8/250_1000.jpg (deflated 1%)
#   adding: content/sample_data/8/500_1000.jpg (deflated 1%)
#   adding: content/sample_data/8/0_750.jpg (deflated 1%)
# ...

# %%
gambar9 = cv2.imread('/content/drive/MyDrive/Tugas_Akhir/IMG_20220629_131625.jpg')

# %%
plt.imshow(gambar9)

# %%
gambar9.shape
# Out:
# (2250, 4000, 3)

# %%
for i in range(0, 2250, 250):
  for j in range(0, 4000, 250):
    im9 = Image.fromarray(gambar2[i:i+250,j:j+250])
    im9.save(str(i)+'_'+str(j)+".jpg")

# %%
# !mv *.jpg '/content/sample_data/9'

# %%
# !zip -r hasil9.zip '/content/sample_data/9'
# Out:
#   adding: content/sample_data/9/ (stored 0%)
#   adding: content/sample_data/9/1000_2500.jpg (deflated 1%)
#   adding: content/sample_data/9/1250_2000.jpg (deflated 1%)
#   adding: content/sample_data/9/1750_2250.jpg (deflated 1%)
#   adding: content/sample_data/9/0_3000.jpg (deflated 1%)
#   adding: content/sample_data/9/1750_2000.jpg (deflated 1%)
#   adding: content/sample_data/9/2000_2250.jpg (deflated 1%)
#   adding: content/sample_data/9/750_2250.jpg (deflated 1%)
#   adding: content/sample_data/9/1750_750.jpg (deflated 1%)
#   adding: content/sample_data/9/0_2500.jpg (deflated 1%)
#   adding: content/sample_data/9/1500_750.jpg (deflated 1%)
#   adding: content/sample_data/9/0_3750.jpg (deflated 3%)
#   adding: content/sample_data/9/1500_2750.jpg (deflated 1%)
#   adding: content/sample_data/9/250_1000.jpg (deflated 1%)
#   adding: content/sample_data/9/500_1000.jpg (deflated 1%)
#   adding: content/sample_data/9/0_750.jpg (deflated 1%)
# ...

# %%
gambar10 = cv2.imread('/content/drive/MyDrive/Tugas_Akhir/IMG_20220629_131702 (1).jpg')

# %%
plt.imshow(gambar10)

# %%
gambar10.shape
# Out:
# (2250, 4000, 3)

# %%
for i in range(0, 2250, 250):
  for j in range(0, 4000, 250):
    im10 = Image.fromarray(gambar2[i:i+250,j:j+250])
    im10.save(str(i)+'_'+str(j)+".jpg")

# %%
# !mv *.jpg '/content/sample_data/10'

# %%
# !zip -r hasil10.zip '/content/sample_data/10'
# Out:
#   adding: content/sample_data/10/ (stored 0%)
#   adding: content/sample_data/10/1000_2500.jpg (deflated 1%)
#   adding: content/sample_data/10/1250_2000.jpg (deflated 1%)
#   adding: content/sample_data/10/1750_2250.jpg (deflated 1%)
#   adding: content/sample_data/10/0_3000.jpg (deflated 1%)
#   adding: content/sample_data/10/1750_2000.jpg (deflated 1%)
#   adding: content/sample_data/10/2000_2250.jpg (deflated 1%)
#   adding: content/sample_data/10/750_2250.jpg (deflated 1%)
#   adding: content/sample_data/10/1750_750.jpg (deflated 1%)
#   adding: content/sample_data/10/0_2500.jpg (deflated 1%)
#   adding: content/sample_data/10/1500_750.jpg (deflated 1%)
#   adding: content/sample_data/10/0_3750.jpg (deflated 3%)
#   adding: content/sample_data/10/1500_2750.jpg (deflated 1%)
#   adding: content/sample_data/10/250_1000.jpg (deflated 1%)
#   adding: content/sample_data/10/500_1000.jpg (deflated 1%)
#   adding: content/sample_data/10/0_750.jpg (deflated 1%)
# ...

# %%
gambar11 = cv2.imread('/content/drive/MyDrive/Tugas_Akhir/IMG_20220629_131732.jpg')

# %%
plt.imshow(gambar11)

# %%
gambar11.shape
# Out:
# (2250, 4000, 3)

# %%
for i in range(0, 2250, 250):
  for j in range(0, 4000, 250):
    im11 = Image.fromarray(gambar2[i:i+250,j:j+250])
    im11.save(str(i)+'_'+str(j)+".jpg")

# %%
# !mv *.jpg '/content/sample_data/11'

# %%
# !zip -r hasil11.zip '/content/sample_data/11'
# Out:
# updating: content/sample_data/11/ (stored 0%)
#   adding: content/sample_data/11/1000_2500.jpg (deflated 1%)
#   adding: content/sample_data/11/1250_2000.jpg (deflated 1%)
#   adding: content/sample_data/11/1750_2250.jpg (deflated 1%)
#   adding: content/sample_data/11/0_3000.jpg (deflated 1%)
#   adding: content/sample_data/11/1750_2000.jpg (deflated 1%)
#   adding: content/sample_data/11/2000_2250.jpg (deflated 1%)
#   adding: content/sample_data/11/750_2250.jpg (deflated 1%)
#   adding: content/sample_data/11/1750_750.jpg (deflated 1%)
#   adding: content/sample_data/11/0_2500.jpg (deflated 1%)
#   adding: content/sample_data/11/1500_750.jpg (deflated 1%)
#   adding: content/sample_data/11/0_3750.jpg (deflated 3%)
#   adding: content/sample_data/11/1500_2750.jpg (deflated 1%)
#   adding: content/sample_data/11/250_1000.jpg (deflated 1%)
#   adding: content/sample_data/11/500_1000.jpg (deflated 1%)
#   adding: content/sample_data/11/0_750.jpg (deflated 1%)
# ...

# %%
gambar12 = cv2.imread('/content/drive/MyDrive/Tugas_Akhir/IMG_20220629_131753.jpg')

# %%
plt.imshow(gambar12)

# %%
gambar12.shape
# Out:
# (2250, 4000, 3)

# %%
for i in range(0, 2250, 250):
  for j in range(0, 4000, 250):
    im12 = Image.fromarray(gambar2[i:i+250,j:j+250])
    im12.save(str(i)+'_'+str(j)+".jpg")

# %%
# !mv *.jpg '/content/sample_data/12'

# %%
# !zip -r hasil12.zip '/content/sample_data/12'
# Out:
#   adding: content/sample_data/12/ (stored 0%)
#   adding: content/sample_data/12/1000_2500.jpg (deflated 1%)
#   adding: content/sample_data/12/1250_2000.jpg (deflated 1%)
#   adding: content/sample_data/12/1750_2250.jpg (deflated 1%)
#   adding: content/sample_data/12/0_3000.jpg (deflated 1%)
#   adding: content/sample_data/12/1750_2000.jpg (deflated 1%)
#   adding: content/sample_data/12/2000_2250.jpg (deflated 1%)
#   adding: content/sample_data/12/750_2250.jpg (deflated 1%)
#   adding: content/sample_data/12/1750_750.jpg (deflated 1%)
#   adding: content/sample_data/12/0_2500.jpg (deflated 1%)
#   adding: content/sample_data/12/1500_750.jpg (deflated 1%)
#   adding: content/sample_data/12/0_3750.jpg (deflated 3%)
#   adding: content/sample_data/12/1500_2750.jpg (deflated 1%)
#   adding: content/sample_data/12/250_1000.jpg (deflated 1%)
#   adding: content/sample_data/12/500_1000.jpg (deflated 1%)
#   adding: content/sample_data/12/0_750.jpg (deflated 1%)
# ...

# %%
gambar13 = cv2.imread('/content/drive/MyDrive/Tugas_Akhir/IMG_20220629_131819.jpg')

# %%
plt.imshow(gambar13)

# %%
gambar13.shape
# Out:
# (2250, 4000, 3)

# %%
for i in range(0, 2250, 250):
  for j in range(0, 4000, 250):
    im = Image.fromarray(gambar2[i:i+250,j:j+250])
    im.save(str(i)+'_'+str(j)+".jpg")

# %%
# !mv *.jpg '/content/sample_data/13'

# %%
# !zip -r hasil13.zip '/content/sample_data/13'
# Out:
#   adding: content/sample_data/13/ (stored 0%)
#   adding: content/sample_data/13/1000_2500.jpg (deflated 1%)
#   adding: content/sample_data/13/1250_2000.jpg (deflated 1%)
#   adding: content/sample_data/13/1750_2250.jpg (deflated 1%)
#   adding: content/sample_data/13/0_3000.jpg (deflated 1%)
#   adding: content/sample_data/13/1750_2000.jpg (deflated 1%)
#   adding: content/sample_data/13/2000_2250.jpg (deflated 1%)
#   adding: content/sample_data/13/750_2250.jpg (deflated 1%)
#   adding: content/sample_data/13/1750_750.jpg (deflated 1%)
#   adding: content/sample_data/13/0_2500.jpg (deflated 1%)
#   adding: content/sample_data/13/1500_750.jpg (deflated 1%)
#   adding: content/sample_data/13/0_3750.jpg (deflated 3%)
#   adding: content/sample_data/13/1500_2750.jpg (deflated 1%)
#   adding: content/sample_data/13/250_1000.jpg (deflated 1%)
#   adding: content/sample_data/13/500_1000.jpg (deflated 1%)
#   adding: content/sample_data/13/0_750.jpg (deflated 1%)
# ...

# %%
gambar14 = cv2.imread('/content/drive/MyDrive/Tugas_Akhir/IMG_20220629_131908.jpg')

# %%
plt.imshow(gambar14)

# %%
gambar14.shape
# Out:
# (2250, 4000, 3)

# %%
for i in range(0, 2250, 250):
  for j in range(0, 4000, 250):
    im = Image.fromarray(gambar2[i:i+250,j:j+250])
    im.save(str(i)+'_'+str(j)+".jpg")

# %%
# !mv *.jpg '/content/sample_data/14'

# %%
# !zip -r hasil14.zip '/content/sample_data/14'
# Out:
#   adding: content/sample_data/14/ (stored 0%)
#   adding: content/sample_data/14/1000_2500.jpg (deflated 1%)
#   adding: content/sample_data/14/1250_2000.jpg (deflated 1%)
#   adding: content/sample_data/14/1750_2250.jpg (deflated 1%)
#   adding: content/sample_data/14/0_3000.jpg (deflated 1%)
#   adding: content/sample_data/14/1750_2000.jpg (deflated 1%)
#   adding: content/sample_data/14/2000_2250.jpg (deflated 1%)
#   adding: content/sample_data/14/750_2250.jpg (deflated 1%)
#   adding: content/sample_data/14/1750_750.jpg (deflated 1%)
#   adding: content/sample_data/14/0_2500.jpg (deflated 1%)
#   adding: content/sample_data/14/1500_750.jpg (deflated 1%)
#   adding: content/sample_data/14/0_3750.jpg (deflated 3%)
#   adding: content/sample_data/14/1500_2750.jpg (deflated 1%)
#   adding: content/sample_data/14/250_1000.jpg (deflated 1%)
#   adding: content/sample_data/14/500_1000.jpg (deflated 1%)
#   adding: content/sample_data/14/0_750.jpg (deflated 1%)
# ...

# %%
gambar15 = cv2.imread('/content/drive/MyDrive/Tugas_Akhir/IMG_20220629_131942.jpg')

# %%
plt.imshow(gambar15)

# %%
gambar15.shape
# Out:
# (2250, 4000, 3)

# %%
for i in range(0, 2250, 250):
  for j in range(0, 4000, 250):
    im = Image.fromarray(gambar2[i:i+250,j:j+250])
    im.save(str(i)+'_'+str(j)+".jpg")

# %%
# !mv *.jpg '/content/sample_data/15'

# %%
# !zip -r hasil15.zip '/content/sample_data/15'
# Out:
#   adding: content/sample_data/15/ (stored 0%)
#   adding: content/sample_data/15/1000_2500.jpg (deflated 1%)
#   adding: content/sample_data/15/1250_2000.jpg (deflated 1%)
#   adding: content/sample_data/15/1750_2250.jpg (deflated 1%)
#   adding: content/sample_data/15/0_3000.jpg (deflated 1%)
#   adding: content/sample_data/15/1750_2000.jpg (deflated 1%)
#   adding: content/sample_data/15/2000_2250.jpg (deflated 1%)
#   adding: content/sample_data/15/750_2250.jpg (deflated 1%)
#   adding: content/sample_data/15/1750_750.jpg (deflated 1%)
#   adding: content/sample_data/15/0_2500.jpg (deflated 1%)
#   adding: content/sample_data/15/1500_750.jpg (deflated 1%)
#   adding: content/sample_data/15/0_3750.jpg (deflated 3%)
#   adding: content/sample_data/15/1500_2750.jpg (deflated 1%)
#   adding: content/sample_data/15/250_1000.jpg (deflated 1%)
#   adding: content/sample_data/15/500_1000.jpg (deflated 1%)
#   adding: content/sample_data/15/0_750.jpg (deflated 1%)
# ...
